# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.utils import to_categorical

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Preprocess data
x_train = x_train.reshape((x_train.shape[0], 28, 28, 1)).astype('float32') / 255
x_test = x_test.reshape((x_test.shape[0], 28, 28, 1)).astype('float32') / 255
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# Build model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(100, activation='relu'),
    Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train model
model.fit(x_train, y_train, epochs=5, batch_size=64, validation_data=(x_test, y_test))

# Evaluate model
_, accuracy = model.evaluate(x_test, y_test)
print("Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Epoch 1/5
# 938/938 [==============================] - 34s 34ms/step - loss: 0.1902 - accuracy: 0.9440 - val_loss: 0.0781 - val_accuracy: 0.9754
# Epoch 2/5
# 938/938 [==============================] - 26s 28ms/step - loss: 0.0619 - accuracy: 0.9812 - val_loss: 0.0505 - val_accuracy: 0.9834
# Epoch 3/5
# 938/938 [==============================] - 26s 28ms/step - loss: 0.0407 - accuracy: 0.9879 - val_loss: 0.0427 - val_accuracy: 0.9853
# Epoch 4/5
# 938/938 [==============================] - 26s 28ms/step - loss: 0.0301 - accuracy: 0.9910 - val_loss: 0.0535 - val_accuracy: 0.9829
# Epoch 5/5
# 938/938 [==============================] - 26s 28ms/step - loss: 0.0216 - accuracy: 0.9931 - val_loss: 0.0415 - val_accuracy: 0.9863
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0415 - accuracy: 0.9863
# Accuracy: 98.63%
